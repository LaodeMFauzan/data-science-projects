# %%
import numpy as np
import pandas as pd

# %%
data_preprocessed = pd.read_csv('Absenteeism_preprocess.csv', index  =)

data_preprocessed
# Out:
#      Unnamed: 0  Month  Day of The Week  Transportation Expense  \
# 0             0      7                1                     289
# 1             1      7                1                     118
# 2             2      7                2                     179
# 3             3      7                3                     279
# 4             4      7                3                     289
# 5             5      7                4                     179
# 6             6      7                4                     361
# 7             7      7                4                     260
# 8             8      7                0                     155
# 9             9      7                0                     235
# 10           10      7                0                     260
# 11           11      7                1                     260
# 12           12      7                2                     260
# 13           13      7                2                     179
# ...
